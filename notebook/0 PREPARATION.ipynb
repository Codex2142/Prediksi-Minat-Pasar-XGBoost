# %% [markdown]
# # Import Lib

# %%
import gdown
import os

# %% [markdown]
# # Tahap download CSV

# %% [markdown]
# * Pastikan koneksi lancar  dan membutuhkan 500mb penyimpanan

# %%
os.makedirs("../dataset/raw", exist_ok=True)

files = {
    "calendar.csv": "1P22V8M8EY28dmigNW0gS_TqBH8Y3Rwba",
    "sales_train_evaluation.csv": "1mLK9h7aMsM3lgco9UIs7wGXYeLXQ9fmP",
    "sales_train_validation.csv": "1sftR8_l0QVmeZmT1mkdRYoBGVp6vJtSC",
    "sample_submission.csv": "1-IW1kAVLK2b_gZ9CzKaxB7RBSie5T2FN",
    "sell_prices.csv": "1aPt4zbe_2UGJmK2cKNmzu7bkyECWHKRb"
}

for filename, file_id in files.items():
    url = f"https://drive.google.com/uc?id={file_id}"
    save_path = f"../dataset/raw/{filename}"
    gdown.download(url, save_path, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1P22V8M8EY28dmigNW0gS_TqBH8Y3Rwba
# To: e:\Riwayat Kuliah\Semester 7\Big Data dan AI\UAS\dataset\raw1\calendar.csv
# 100%|██████████| 103k/103k [00:00<00:00, 1.29MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1mLK9h7aMsM3lgco9UIs7wGXYeLXQ9fmP
# From (redirected): https://drive.google.com/uc?id=1mLK9h7aMsM3lgco9UIs7wGXYeLXQ9fmP&confirm=t&uuid=409a80f3-8f18-4d26-8cab-88ffcf40445c
# To: e:\Riwayat Kuliah\Semester 7\Big Data dan AI\UAS\dataset\raw1\sales_train_evaluation.csv
# 100%|██████████| 122M/122M [00:11<00:00, 10.8MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1sftR8_l0QVmeZmT1mkdRYoBGVp6vJtSC
# From (redirected): https://drive.google.com/uc?id=1sftR8_l0QVmeZmT1mkdRYoBGVp6vJtSC&confirm=t&uuid=86f76117-873c-48be-bd20-f8ef3ef0c89a
# To: e:\Riwayat Kuliah\Semester 7\Big Data dan AI\UAS\dataset\raw1\sales_train_validation.csv
# 100%|██████████| 120M/120M [00:17<00:00, 6.88MB/s]
# Downloading...
# From: https://drive.google.com/uc?id=1-IW1kAVLK2b_gZ9CzKaxB7RBSie5T2FN
# To: e:\Riwayat Kuliah\Semester 7\Big Data dan AI\UAS\dataset\raw1\sample_submission.csv
# 100%|██████████| 5.23M/5.23M [00:00<00:00, 6.00MB/s]
# Downloading...
# From (original): https://drive.google.com/uc?id=1aPt4zbe_2UGJmK2cKNmzu7bkyECWHKRb
# From (redirected): https://drive.google.com/uc?id=1aPt4zbe_2UGJmK2cKNmzu7bkyECWHKRb&confirm=t&uuid=b0932511-d566-43d8-bd19-474a43ce0e30
# To: e:\Riwayat Kuliah\Semester 7\Big Data dan AI\UAS\dataset\raw1\sell_prices.csv
# 100%|██████████| 203M/203M [00:23<00:00, 8.53MB/s]
